# %%
print("Hello EuroPython!")
# Out:
# Hello EuroPython!

# %%
import numpy as np  
a = np.array([1, 2, 3, 4])
print(a)
A = np.array([1, 2, 3, 4])
A_t = A[:, np.newaxis]
print(A_t)
print(A_t.shape)
A = np.array([[1, 2, 3, 4]])
print(A)
print(A.T)
# Out:
# [1 2 3 4]
# [[1]
#  [2]
#  [3]
#  [4]]
# (4, 1)
# [[1 2 3 4]]
# [[1]
#  [2]
#  [3]
#  [4]]

# %%
1 / 100
# Out:
# 0.01
